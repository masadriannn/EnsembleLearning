# %% [markdown]
# ## 1. Import some Libraries, Read Dataset and Exploratory Dataset using Pandas

# %%
"""
Meng-import beberapa library dari bahasa pemrograman python yang bertujuan
untuk eksplorasi, membersihkan/mentransformasikan data serta pembuatan grafik visualisasi untuk di analisis
"""
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("fast")
from sklearn.preprocessing import LabelEncoder

# %%
# Melakukan proses pembacaan dataset dari sub-folder "Dataset" serta menampilkan 17 data teratas
data_patient_treatment = pd.read_csv("../Dataset/patient_treatment_classification_dataset.csv")

data_patient_treatment.head(17)
# Out:
#     HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 0          35.1          11.8         4.65        6.3          310  25.4
# 1          43.5          14.8         5.39       12.7          334  27.5
# 2          33.5          11.3         4.74       13.2          305  23.8
# 3          39.1          13.7         4.98       10.5          366  27.5
# 4          30.9           9.9         4.23       22.1          333  23.4
# 5          34.3          11.6         4.53        6.6          185  25.6
# 6          31.1           8.7         5.06       11.1          416  17.2
# 7          40.3          13.3         4.73        8.1          257  28.1
# 8          33.6          11.5         4.54       11.4          262  25.3
# 9          35.4          11.4         4.80        2.6          183  23.8
# 10         33.7          11.5         4.57       13.2          322  25.2
# 11         54.0          16.6         7.61       10.0           88  21.8
# ...

# %% [markdown]
# Berikut adalah informasi atas penjelasan lengkap mengenai 11 kolom data yang ada di dalam variabel DataFrame yang bernama "data_patient_treatment" diantaranya adalah sebagai berikut:
#
# 1. HAEMATOCRIT: Kolom yang berisikan data terkait hasil uji laboratorium mengenai hematokrit pasien yaitu hasil tes darah lengkap yang digunakan untuk mendiagnosis pasien terhadap suatu penyakit sehingga dapat mendeteksi apakah pasien tersebut menderita anemia (kekurangan darah) atau tidak.
# 2. HAEMOGLOBINS: Kolom yang berisikan data terkait hasil uji laboratorium mengenai jumlah protein yang ada di dalam sel darah merah (eritrorit) milik masing-masing pasien.
# 3. ERYTHROCYTE: Kolom yang berisikan data terkait hasil uji laboratorium mengenai eritrosit atau sel darah merah milik masing-masing pasien.
# 4. LEUCOCYTE: Kolom yang berisikan data terkait hasil uji laboratorium mengenai leukosit/sel darah putih milik masing-masing pasien.
# 5. THROMBOCYTE: Kolom yang berisikan data terkait hasil uji laboratorium mengenai jumlah trombosit pada masing-masing pasien. Trombosit bertujuan untuk membekukan darah jika terjadi suatu pendarahan.
# 6. MCH: Kolom yang berisikan data terkait hasil uji laboratorium terhadap masing-masing pasien mengenai MCH atau Mean Corpuscular Hemoglobin. MCH merupakan jumlah rata-rata hemoglobin di dalam sel darah merah milik pasien.
# 7. MCHC: Kolom yang berisikan data terkait hasil uji lab pasien mengenai MCHC atau Mean Corpuscular Hemoglobin Concentration. MCHC merupakan perhitungan rata-rata terhadap konsentrasi hemoglobin di dalam eritrosit pasien.
# 8. MCV: Kolom yang berisikan data terkait hasil uji lab pasien mengenai MCV atau Mean Corpuscular Volume. MCV merupakan ukuran rata-rata dari sel darah merah milik pasien.
# 9. AGE: Kolom yang berisikan data mengenai umur dari setiap pasien.
# 10. SEX: Kolom yang berisikan data mengenai jenis kelamin pasien yang ditandai dengan nilai F (female/perempuan) dan M (male/laki-laki).
# 11. SOURCE: Terakhir adalah kolom yang berisikan data dari masing-masing status pasien apakah pasien tersebut merupakan pasien rawat inap (ditandai dengan data "in") atau pasien rawat jalan (ditulis/ditandai dengan data "out"). Kolom ini juga merupakan kolom target yang akan dijadikan sebagai label klasifikasi pada tahap pemodelan machine learning.
#
# Selain informasi atas 11 kolom yang ada di dalam "data_patient_treatment" yang sudah dijelaskan di atas, kalian dapat mengunjungi sumber dataset dari Kaggle melalui link di bawah ini:
#
# https://www.kaggle.com/datasets/saurabhshahane/patient-treatment-classification
#
# Eksplorasi selanjutnya setelah menampilkan 17 data teratas dari "data_patient_treatment" adalah membuktikan apakah variabel "data_patient_treatment" merupakan sebuah DataFrame atau Series dengan cara mengetahui dimensi dari "data_patient_treatment". Jika dimensinya adalah 1 maka variabel "data_patient_treatment" merepresentasikan sebagai Series sedangkan jika dimensinya adalah 2 maka merepresentasikan sebagai DataFrame.

# %%
"""
Menampilkan nilai dimensi yang dimiliki oleh variabel "data_patient_treatment"
untuk mengetahui apakah variabel tersebut merupakan Series/DataFrame
"""
print("Nilai Dimensi dari Variabel 'data_patient_treatment' adalah (1: Series | 2: DataFrame): ", data_patient_treatment.ndim)
# Out:
# Nilai Dimensi dari Variabel 'data_patient_treatment' adalah (1: Series | 2: DataFrame):  2

# %%
# Menampilkan 5 data terbawah yang ada di dalam variabel DataFrame "data_patient_treatment"
data_patient_treatment.tail()
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 4407         32.8          10.4         3.49        8.1           72  29.8
# 4408         33.7          10.8         3.67        6.7           70  29.4
# 4409         33.2          11.2         3.47        7.2          235  32.3
# 4410         31.5          10.4         3.15        9.1          187  33.0
# 4411         33.5          10.9         3.44        5.8          275  31.7
#
#       MCHC    MCV  AGE SEX SOURCE
# 4407  31.7   94.0   92   F     in
# 4408  32.0   91.8   92   F     in
# 4409  33.7   95.7   93   F    out
# 4410  33.0  100.0   98   F     in
# 4411  32.5   97.4   99   F    out

# %%
# Menampilkan jumlah baris dan kolom yang dimiliki oleh variabel "data_patient_treatment" secara terpisah
print("1. Menampilkan Jumlah Baris dan Kolom Data secara Terpisah: ")
print("Jumlah Baris Data yang Dimiliki oleh Variabel DataFrame 'data_patient_treatment': ", len(data_patient_treatment))

print("Jumlah Kolom yang Dimiliki oleh Variabel DataFrame 'data_patient_treatment': ",
      len(data_patient_treatment.columns), "\n")

# Menampilkan jumlah baris dan kolom dari variabel "data_patient_treatment" tanpa terpisah
print("2. Menampilkan Jumlah Baris dan Kolom tanpa Terpisah: ")
print("Jumlah Baris dan Kolom Data dari Variabel DataFrame 'data_patient_treatment': ", data_patient_treatment.shape)
# Out:
# 1. Menampilkan Jumlah Baris dan Kolom Data secara Terpisah:
# Jumlah Baris Data yang Dimiliki oleh Variabel DataFrame 'data_patient_treatment':  4412
# Jumlah Kolom yang Dimiliki oleh Variabel DataFrame 'data_patient_treatment':  11
#
# 2. Menampilkan Jumlah Baris dan Kolom tanpa Terpisah:
# Jumlah Baris dan Kolom Data dari Variabel DataFrame 'data_patient_treatment':  (4412, 11)

# %%
# Menampilkan nama kolom dari variabel "data_patient_treatment"
data_patient_treatment.columns
# Out:
# Index(['HAEMATOCRIT', 'HAEMOGLOBINS', 'ERYTHROCYTE', 'LEUCOCYTE',
#        'THROMBOCYTE', 'MCH', 'MCHC', 'MCV', 'AGE', 'SEX', 'SOURCE'],
#       dtype='object')

# %% [markdown]
# Berdasarkan hasil diatas dapat diketahui jika variabel DataFrame "data_patient_treatment" memiliki 4.412 data yang tersebar ke dalam 11 kolom berbeda. Kesebelas kolom tersebut adalah HAEMATOCRIT, HAEMOGLOBINS, ERYTHROCYTE, LEUCOCYTE, THROMBOCYTE, MCH, MCHC, MCV, AGE, SEX dan SOURCE.
#
# Namun jika diperhatikan penamaan kolom tersebut masih belum tepat serta ditulis menggunakan huruf kapital sehingga harus di-update menjadi format penamaan kolom yang sesuai. Proses transformasi terhadap penamaan kolom akan dilakukan pada bagian selanjutnya tepatnya pada bagian Data Preprocessing.

# %%
# Menampilkan tipe data apa saja yang dimiliki oleh variabel DataFrame "data_patient_treatment"
data_patient_treatment.dtypes
# Out:
# HAEMATOCRIT     float64
# HAEMOGLOBINS    float64
# ERYTHROCYTE     float64
# LEUCOCYTE       float64
# THROMBOCYTE       int64
# MCH             float64
# MCHC            float64
# MCV             float64
# AGE               int64
# SEX              object
# SOURCE           object
# dtype: object

# %% [markdown]
# Berdasarkan hasil eksplorasi diatas menggunakan fungsi dtypes dari pandas, dapat diketahui bahwa setidaknya ada 3 tipe data yang berbeda yaitu float, int dan object. Tipe data float merupakan tipe data yang menunjukkan/identitas dari data berupa bilangan numerik pecahan. Tipe data int atau integer merupakan tipe data yang menjadi indetitas dari data numerik bilangan bulat. Sedangkan tipe data object merupakan tipe data yang menunjukkan identitas dari data kategorik atau data string seperti huruf, simbol karakter atau gabungan antara bilangan numerik (pecahan/bulat) dengan huruf/angka.

# %%
# Menampilkan jumlah total dari elemen yang dimiliki oleh variabel DataFrame
data_patient_treatment.size
# Out:
# 48532

# %% [markdown]
# Kenapa jumlah total element dari "data_patient_treatment" bernilai 48.532? Hal tersebut dikarenakan jumlah total element yang ada dimiliki oleh fungsi "size" merupakan sebuah bentuk bilangan hasil kalkulasi perkalian antara jumlah baris (number of rows) dengan jumlah kolom (number of columns) yang dimiliki oleh variabel DataFrame (dalam hal ini adalah data_patient_treatment).
#
# Berarti jumlah baris dari "data_patient_treatment" yang bernilai 4.412 * jumlah kolom yang saat ini dimiliki oleh "data_patient_treatment" yaitu 11 sehingga menghasilkan 48.532 element. Untuk lebih jelasnya dapat lihat perhitungan yang ada di bawah ini:
#
# 4412 * 11 = 48532

# %%
# Menampilkan jumlah total data yang terindikasi sebagai data duplikat
data_patient_treatment.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Hasil diatas menunjukkan bahwa data yang dimiliki oleh "data_patient_treatment" tidak ada yang terduplikasi. Data duplikat merupakan data yang memiliki nilai yang sama di setiap kolomnya serta pada baris yang lain juga terdapat nilai data yang serupa. Selanjutnya saya akan mengecek apakah di dalam "data_patient_treatment" terdapat missing value di masing-masing kolom atau tidak dengan menggunakan fungsi "isnull()" dan "sum()".

# %%
"""
Menampilkan jumlah keseluruhan missing value yang dimiliki oleh
masing-masing kolom dari variabel DataFrame "data_patient_treatment"
"""
data_patient_treatment.isnull().sum()
# Out:
# HAEMATOCRIT     0
# HAEMOGLOBINS    0
# ERYTHROCYTE     0
# LEUCOCYTE       0
# THROMBOCYTE     0
# MCH             0
# MCHC            0
# MCV             0
# AGE             0
# SEX             0
# SOURCE          0
# dtype: int64

# %% [markdown]
# Menggunakan fungsi "isnull()" dan "sum()" secara bersamaan bertujuan untuk menghitung jumlah total keseluruhan dari data yang hilang (missing value) dari masing-masing kolom yang ada di dalam variabel DataFrame "data_patient_treatment". Dengan menggabungkan kedua fungsi tersebut dapat secara cepat dan tepat mengetahui berapa banyak missing value/data yang hilang dari masing-masing kolom yang berada di dalam variabel DataFrame "data_patient_treatment".

# %%
"""
Menampilkan ringkasan informasi singkat yang dimiliki oleh DataFrame, baik informasi per masing-masing
kolom seperti missing value, tipe data, dll, informasi jumlah kolom & baris dan penggunaan memori
"""
data_patient_treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4412 entries, 0 to 4411
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HAEMATOCRIT   4412 non-null   float64
#  1   HAEMOGLOBINS  4412 non-null   float64
#  2   ERYTHROCYTE   4412 non-null   float64
#  3   LEUCOCYTE     4412 non-null   float64
#  4   THROMBOCYTE   4412 non-null   int64
#  5   MCH           4412 non-null   float64
#  6   MCHC          4412 non-null   float64
#  7   MCV           4412 non-null   float64
#  8   AGE           4412 non-null   int64
#  9   SEX           4412 non-null   object
#  10  SOURCE        4412 non-null   object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 379.3+ KB

# %% [markdown]
# Berdasarkan output yang didapatkan dari fungsi "info()", kita dapat mengetahui beberapa informasi yang penting terkait variabel DataFrame "data_patient_treatment" diantaranya adalah sebagai berikut:
#
# 1. Variabel "data_patient_treatment" merupakan sebuah DataFrame yang berisikan sebuah dataset tentang hasil pemeriksaan laboratorium untuk pasien yang digunakan untuk menentukan penanganan pasien selanjutnya apakah pasien tersebut harus di rawat inap atau rawat jalan.
# 2. Variabel DataFrame "data_patient_treatment" memiliki jumlah data/baris sebanyak 4.412 data. Selain itu, variabel "data_patient_treatment" memiliki 11 kolom yang diantaranya adalah "HAEMATOCRIT", "HAEMOGLOBINS", "ERYTHROCTYE", "LEUCOCYTE", "THROMBOCYTE", "MCH", "MCHC", "MCV", "AGE", "SEX" dan "SOURCE".
# 3. Setiap kolom yang ada di dalam "data_patient_treatment" tidak memiliki nilai NaN atau nilai kosong di dalam kolom-kolom data. Itu berarti kesebelas kolom yang ada di dalam "data_patient_treatment" tidak memiliki missing value di dalamnya.
# 4. Terdapat 3 variasi tipe data yang ada di dalam variabel DataFrame "data_patient_treatment" yaitu tipe data float untuk data angka pecahan. Tipe data int (integer) untuk data angka bilangan bulat dan tipe data object (string) yang merupakan data karakter & huruf.
# 5. Tipe data yang paling banyak digunakan oleh kolom-kolom dari "data_patient_treatment" adalah float sedangkan tipe data int atau object (string) hanya digunakan oleh masing-masing 2 kolom saja. Teruntuk kolom yang menggunakan tipe data float adalah "HAEMATOCRIT", "HAEMOGLOBINS", "ERYHROCYTE", "LEUCOCYTE", "MCH", "MCHC" dan "MCV". Lalu kolom yang menggunakan tipe data int adalah "THROMBOCYTE" dan "AGE". Terakhir adalah kolom "SEX" dan "SOURCE" yang menggunakan tipe data object (string).

# %%
"""
Menampilkan nilai statistik deskriptif untuk kolom bersifat angka
numerik (float & int) yang ada di dalam "data_patient_treatment"
"""
data_patient_treatment.describe()
# Out:
#        HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE    LEUCOCYTE  THROMBOCYTE  \
# count  4412.000000   4412.000000  4412.000000  4412.000000  4412.000000
# mean     38.197688     12.741727     4.541260     8.718608   257.524479
# std       5.974784      2.079903     0.784091     5.049041   113.972365
# min      13.700000      3.800000     1.480000     1.100000     8.000000
# 25%      34.375000     11.400000     4.040000     5.675000   188.000000
# 50%      38.600000     12.900000     4.570000     7.600000   256.000000
# 75%      42.500000     14.200000     5.050000    10.300000   321.000000
# max      69.000000     18.900000     7.860000    76.600000  1183.000000
#
#                MCH         MCHC          MCV          AGE
# count  4412.000000  4412.000000  4412.000000  4412.000000
# mean     28.234701    33.343042    84.612942    46.626473
# std       2.672639     1.228664     6.859101    21.731218
# min      14.900000    26.000000    54.000000     1.000000
# ...

# %% [markdown]
# Berdasarkan hasil diatas terkait menampilkan nilai statistik untuk kolom yang bersifat/memiliki data angka, dapat diketahui bahwa nilai-nilai statistik dari kolom seperti "HAEMATOCRIT", "HAEMOGLOBINS", "ERYTHROCYTE", "LEUCOCYTE", "THROMBOCYTE", "MCH", "MCHC", MCV" dan kolom "AGE" adalah nilai count, mean/average, std/standar deviasi, min, 25% atau quartil 1, 50% atau quartil 2, 75% atau quartil 3 dan max. Delapan nilai statistik deskriptif tersebut secara default diperuntukkan untuk kolom-kolom yang memiliki data angka baik angka pecahan/bilangan bulat.
#
# Sedangkan kolom seperti "SEX" dan "SOURCE" tidak memiliki delapan nilai statistik tersebut dikarenakan kedua kolom tersebut bersifat kategorikal yang datanya merupakan data huruf dan karakter. Jika ingin melihat nilai statistik deskriptif untuk kolom yang bersifat memiliki tipe data object (string) kita dapat menggunakan kedua cara berikut ini:
#
# 1. Cara pertama adalah dengan menuliskan script data_patient_treatment.describe(include="O") jika hanya ingin melihat nilai statistik deskriptif untuk kolom yang memiliki tipe data object.
#
# 2. Atau cara kedua adalah adalah dengan data_mentari_niaga.describe(include="all"). Jika menggunakan cara kedua maka seluruh kolom akan menampilkan nilai statistik deskriptifnya masing-masing.
#
# Untuk mengetahui/mengambil kesimpulan secara tepat terkait nilai statistik untuk kolom yang ada di dalam variabel DataFrame "data_patient_treatment", maka dapat dibaca penjelasan di bawah ini:
#
# 1. Kolom "HAEMOGLOBINS" memiliki nilai statistik minimum sebesar 4 (3.800000) dan nilai statistik maximum sebesar 19 (18.900000). Selain kedua nilai statistik tersebut (minimum dan maximum), nilai statistik mean/average untuk kolom ini adalah sebesar 13 (12.741727) dengan nilai standar deviasi yaitu 2 (2.079903). Lalu untuk nilai quartil pertama (25%) dari kolom "HAEMOGLOBINS" adalah 11 (11.400000), quartil kedua (50%) atau yang diketahui juga sebagai nilai median menghasilkan nilai 13 (12.900000), dan statistik deskriptif quartil ketiga (75%) memiliki nilai sebesar 14 (14.200000).
#
# 2. Kolom kedua yang akan dibahas nilai statistik deskriptifnya adalah "ERYTHROCYTE" dengan nilai statistik yang pertama yaitu maximum yang memiliki nilai sebesar 8 (7.860000) serta nilai statistik minimum yang dimiliki oleh kolom ini adalah 1 (1.480000). Selain kedua nilai statistik tersebut (maximum dan minimum), kolom "ERYTHROCYTE" memiliki nilai mean dan nilai mean yang dimiliki oleh kolom ini adalah 5 (4.541260) dan nilai standar deviasi yaitu 1 (0.784091). Lalu untuk nilai quartil pertama (25%) yang dimiliki oleh kolom ini adalah 4 (4.040000), quartil kedua (50%) atau yang diketahui juga sebagai nilai median memiliki nilai 5 (4.570000), dan statistik deskriptif untuk quartil ketiga (75%) memiliki nilai sebesar 5 (5.050000).
#
# 3. Kolom ketiga yang akan dibahas nilai statistik deskriptifnya adalah "MCV" dengan nilai statistik yang pertama yaitu maximum yang memiliki nilai sebesar 116 (115.600000) serta nilai statistik minimum yang dimiliki oleh kolom ini adalah 54 (54.000000). Selain kedua nilai statistik tersebut (maximum dan minimum), kolom "MCV" memiliki nilai mean dan nilai mean yang dimiliki oleh kolom ini adalah 85 (84.612942) dan nilai standar deviasi yaitu 7 (6.859101). Lalu untuk nilai quartil pertama (25%) yang dimiliki oleh kolom ini adalah "MCV" adalah 82 (81.500000), quartil kedua (50%) atau yang diketahui juga sebagai nilai median memiliki nilai 85 (85.400000), dan statistik deskriptif untuk quartil ketiga (75%) memiliki nilai sebesar 89 (88.700000).
#
# 4. Kolom keempat yang akan dibahas nilai statistik deskriptifnya adalah "THROMBOCYTE". Nilai statistik pertama yang dimiliki oleh kolom ini adalah nilai rata-rata (mean) yang sebesar 258 (257.524479). Lalu nilai statistik kedua yaitu minimum dengan nilai 8 (8.000000) dan nilai statistik maximum sebesar 1.183 (1183.000000). Selain ketiga nilai statistik tersebut (mean, minimum dan maximum), sebagai kolom yang berisikan data numerik bilangan pecahan juga sudah pasti memiliki nilai statistik yaitu standar deviasi, quartil pertama (25%), quartil kedua/median (50%) dan quartil ketiga (75%). Nilai standar deviasi yang dimiliki oleh kolom "THROMBOCYTE" yaitu 114 (113.972365), nilai quartil pertama (25%) adalah 188 (188.000000), quartil kedua (50%) sebesar 256, dan quartil ketiga (75%) dengan nilai 321 (321.000000).
#
# 5. Kolom terakhir yang akan dijadikan contoh bagaimana caranya mengambil kesimpulan/mendapatkan informasi atas interpretasi nilai statistik deskriptif melalui fungsi "describe()" dari library pandas adalah kolom "AGE". Nilai statistik pertama yang dimiliki oleh kolom ini adalah nilai rata-rata (mean) dengan nilai mean sebesar 47 (46.626473). Lalu nilai statistik kedua dan ketiga yang dimiliki yaitu standar deviasi dengan nilai 22 (21.731218) dan nilai statistik minimum yaitu 1 (1.000000). Selain ketiga nilai statistik tersebut (mean, standar deviasi dan minimum), kolom ini juga memiliki nilai statistik quartil dan maximum. Untuk nilai quartil pertama (25%) adalah 29 (29.000000), quartil kedua/median (50%) adalah 47 (47.000000), quartil ketiga (75%) adalah 64 (64.000000) dan nilai statistik deskriptif terakhir yang ada di kolom "AGE" adalah maximum dengan nilai sebesar 99 (99.000000). Ini berarti umur pasien terkecil (paling kecil dan muda) yang dimiliki oleh dataset yang digunakan di dalam penelitian kali ini berumur 1 tahun dan umur pasien tertinggi (paling tinggi/tua) berumur 99 tahun.

# %%
# Menampilkan nilai statistik deskriptif untuk kolom data kategorik (kolom "SEX" dan "SOURCE")
data_patient_treatment.describe(include="O")
# Out:
#          SEX SOURCE
# count   4412   4412
# unique     2      2
# top        M    out
# freq    2290   2628

# %% [markdown]
# Seperti yang sudah dijelaskan saat menampilkan nilai statistik deskriptif untuk kolom data numerik, salah satu dari cara untuk menampilkan sekaligus mengetahui nilai statistik deskriptif untuk kolom data kategorik adalah dengan cara "variableDataFrame.describe(include="O")" dimana nilai O adalah Object yang itu berarti menampilkan nilai statistik untuk kolom bertipe data object (string).
#
# Hasil output dari fungsi "describe(include="O")" adalah kedua kolom yang ada di dalam variabel "data_patient"treatment" yaitu kolom "SEX" dan "SOURCE" adalah menampilkan nilai statistik yang dimilikinya. Berbeda ketika saat menampilkan nilai statistik untuk kolom data numerik, nilai statistik untuk kolom data string hanya ada 4 nilai statistik saja yaitu count, unique, top dan freq. Nilai count merupakan nilai yang menghitung ada berapa banyak data yang dimiliki oleh masing-masing kolom. Nilai unique merupakan nilai yang memiliki keunikan tersendiri dan tidak sama antar satu dengan yang lainnya. Sebagai contoh nilai unik yang dapat diketahui adalah jenis kelamin hanya ada 2 yaitu Laki-Laki dan Perempuan. Kedua jenis kelamin tersebut termasuk ke dalam kategori nilai unik. Selanjutnya adalah nilai statistik top yang menunjukkan data yang paling banyak muncul di dalam kolom tersebut. Nilai top dapat diketahui secara jelas dengan menggunakan fungsi "value_counts()". Nilai statistik yang terakhir untuk kolom bertipe data object adalah freq yang merupakan jumlah total kemunculan (frekuensi) data yang paling sering terlihat kemunculannya di kolom tersebut. Untuk lebih jelasnya dapat di lihat penjelasan yang ada di bawah ini:
#
# 1. Nilai unique pada kolom "SEX" berjumlah 2 saja yang itu berarti terdapat 2 data yang berbeda pada kolom "SEX". Seperti yang kita tau bahwa jenis kelamin yang ada di dunia hanya ada Laki-Laki dan Perempuan saja. Maka dari itu karena kolom ini menyimpan data jenis kelamin pasien, kolom "SEX" hanya memiliki 2 data unik yang itu berarti jenis kelamin pasien yang tersimpan di dalam Electronic Health Record Predicting yang dikumpulkan dari Rumah Sakit Swasta di Indonesia hanya ada 2 yaitu Laki-Laki dan Perempuan. Selanjutnya dari kedua jenis kelamin tersebut, data yang paling sering terlihat di dalam kolom "SEX" atau dapat dikatakan data yang memiliki jumlah kemunculan terbanyak di kolom "SEX" adalah M atau Male (Laki-Laki). Nilai data M atau Male (Laki-Laki) memiliki jumlah kemunculan (freq) sebanyak 2.290 kali. Jika disimpulkan hal ini berarti kolom "SEX" memiliki data unik yaitu 2 data saja (yaitu Male/Laki-Laki dan Female (F)/Perempuan) dan dari kedua data tersebut, nilai data M/Male yang memiliki jumlah frekuensi kemunculan terbanyak yaitu 2.290 kali.
#
# 2. Terakhir adalah kolom "SOURCE" yang memiliki nilai unique hanya 2 saja yang itu berarti terdapat 2 data yang berbeda pada kolom "SOURCE". Selanjutnya dari kedua data unik tersebut, data yang paling sering terlihat di dalam kolom "SOURCE" atau dapat dikatakan data yang memiliki jumlah kemunculan terbanyak di kolom ini adalah out (out care patient). Nilai data out (out care patient) memiliki jumlah kemunculan (freq) terbanyak yaitu berjumlah 2.628 kali. Jika disimpulkan maka kolom "SOURCE" memiliki 2 data unik (yaitu in dan out. Nilai in untuk pasien yang diklasifikasikan sebagai pasien rawat inap dan nilai out untuk pasien yang dikategorikan sebagai pasien rawat jalan). Kedua data tersebut (in dan out) memiliki data yang paling banyak terlihat di dalam kolom "SOURCE" dan data tersebut adalah out. Nilai data out merupakan data yang paling banyak terlihat di dalam kolom "SOURCE" karena data ini (data out) memiliki jumlah frekuensi kemunculan sebanyak 2.628 kali.

# %%
# Menampilkan jumlah frekuensi dari masing-masing kedua data unik yang dimiliki oleh kolom "SEX" dan "SOURCE"
print(data_patient_treatment["SEX"].value_counts(), "\n")

print(data_patient_treatment["SOURCE"].value_counts())
# Out:
# M    2290
# F    2122
# Name: SEX, dtype: int64
#
# out    2628
# in     1784
# Name: SOURCE, dtype: int64

# %% [markdown]
# Hasil diatas menunjukkan jumlah frekuensi/kemunculan data dari kedua kolom data kategorik yaitu kolom "SEX" dan "SOURCE". Berdasarkan output diatas dapat diketahui bahwa jenis kelamin Laki-Laki/Male (yang ditandai dengan nilai M) memiliki jumlah frekuensi kemunculan data sebanyak 2.290. Jumlah tersebut sudah sangat tepat dengan informasi yang didapatkan ketika menampilkan nilai statistik deskriptif untuk kolom data yang memiliki tipe data object/string. Hal ini berarti menyimpulkan bahwa mayoritas pasien yang melakukan test laboratorium di Rumah Sakit Swasta di Indonesia adalah pasien berjenis kelamin Laki-Laki karena dari 4.412 data yang berhasil tersimpan di dalam Electronic Health Record Predicting, sebanyak 2.290 data mengkategorikan pasien tersebut adalah Laki-Laki sedangkan 2.122 dikategorikan sebagai pasien Perempuan/Female yang di tandai dengan nilai F pada kolom "SEX".
#
# Selain menunjukkan jumlah frekuensi kemunculan data terbanyak dari kolom "SEX" atau jenis kelamin, hasil diatas juga memperlihatkan jumlah kemunculan dua data unik dari kolom "SOURCE" yang diantaranya adalah out dan in. Nilai out merupakan nilai yang menunjukkan status dari seorang pasien rawat jalan sedangkan nilai in merupakan nilai yang menunjukkan status seorang pasien rawat inap. Pasien rawat jalan yang memiliki nilai out di dalam kolom "SOURCE" memiliki jumlah frekuensi kemunculan nilai paling banyak yaitu 2.628 sedangkan pasien rawat inap yang memiliki nilai in hanya memiliki jumlah frekuensi kemunculan nilai yaitu 1.784.

# %%
# Menampilkan nilai korelasi antar masing-masing kolom bertipe data int & float dari variabel DataFrame "data_patient_treatment"
data_patient_treatment.corr()
# Out:
# /var/folders/1w/ny22xf_d3fn4s24vv_lvl2n00000gn/T/ipykernel_24370/2820146313.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_patient_treatment.corr()
#               HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE  \
# HAEMATOCRIT      1.000000      0.973267     0.864989  -0.217218    -0.003562
# HAEMOGLOBINS     0.973267      1.000000     0.818013  -0.208583    -0.045441
# ERYTHROCYTE      0.864989      0.818013     1.000000  -0.186711     0.025879
# LEUCOCYTE       -0.217218     -0.208583    -0.186711   1.000000     0.283262
# THROMBOCYTE     -0.003562     -0.045441     0.025879   0.283262     1.000000
# MCH              0.083714      0.203248    -0.383666  -0.014840    -0.138058
# MCHC             0.108098      0.314159    -0.048313   0.003194    -0.198921
# ...

# %% [markdown]
# Dengan menggunakan fungsi "corr()" pada variabel "data_patient_treatment" dapat memperlihatkan nilai korelasi/hubungan timbal-balik antar masing-masing kolom tetapi dengan 1 syarat yaitu kolom tersebut harus memiliki data numerik/angka yang itu berarti fungsi "corr()" diperuntukkan untuk kolom bertipe data integer/float.
#
# Agar mendapatkan informasi apakah suatu kolom memiliki hubungan sebab-akibat yang sangat kuat dapat dilihat melalui nilai output yang dihasilkan oleh fungsi "corr()" pada variabel "data_patient_treatment". Berikut adalah beberapa contoh penjelasan terkait nilai korelasi yang dimiliki oleh masing-masing kolom di dalam variabel "data_patient_treatment":
#
# 1. Kolom "HAEMATOCRIT" memiliki hubungan sebab-akibat/timbal-balik yang sangat tinggi dengan kolom "HAEMOGLOBINS" dikarenakan nilai korelasi yang dihasilkan oleh kedua kolom tersebut adalah 0.973267. Itu berarti kolom "HAEMATOCRIT" dan "HAEMOGLOBINS" saling memiliki keterkaitan dari data yang dimiliki oleh kedua kolom tersebut. Berbanding terbalik jika kita melihat nilai korelasi antara kolom "HAEMATOCRIT" dengan kolom "THROMBOCYTE" yang hanya -0.003562. Itu berati kedua kolom tersebut tidak memiliki keterkaitan/hubungan timbal-balik yang bagus antar masing-masing data yang dihasilkan.
#
# 2. Contoh kedua yang akan dijadikan contoh penjelasan mengenai keterkaitan/hubungan sebab-akibat antar kolom yaitu "HAEMOGLOBINS" dengan "ERYTHROCYTE". Kedua kolom ini memiliki hubungan sebab-akibat yang cukup dekat karena nilai korelasi yang dihasilkan oleh kedua kolom tersebut adalah 0.818013. Sangat berbanding terbalik jika kita melihat hubungan sebab-akibat antara kolom "HAEMOGLOBINS" dengan "LEUCOCYTE", "THROMBOCYTE" ataupun "AGE" yang sama-sama memiliki nilai korelasi minus yaitu -0.208583 (LEUCOCYTE), -0.045441	(THROMBOCYTE) dan -0.239480 (AGE). Itu sudah cukup menjelaskan dan menjadi bukti bahwa kolom "HAEMOGLOBINS" dengan ketiga kolom yaitu "LEUCOCYTE", "THROMBOCYTE" ataupun "AGE" tidak memiliki keterkaitan hubungan antar data.
#
# 3. Selanjutnya adalah hubungan timbal-balik yang dimiliki oleh kolom "MCH" dan "MCV" yang memiliki keterkaitan antar data di masing-masing kedua kolom tersebut sangat dekat. Hal tersebut dikarenakan nilai korelasi yang dimiliki oleh kedua kolom ini (kolom "MCH" dah "MCV) sangat tinggi dan hampir mendekati kesempurnaan (sama seperti korelasi antara kolom "HAEMATOCRIT" dan "HAEMOGLOBINS") yaitu 0.931804.
#
# 4. Hubungan sebab-akibat dari data yang dimiliki oleh kolom "ERYTHROCYTE" dengan beberapa kolom seperti "LEUCOCYTE", "MCH", "MCHC", "MCV" dan "AGE" sangat rendah karena nilai korelasinya berada di bawah minus. Korelasi/keterkaitan hubungan data antara kolom "ERYTHROCYTE" dengan kolom "LEUCOCYTE" adalah -0.186711, kolom "ERYTHROCYTE" dengan "MCH" adalah -0.383666, dengan kolom "MCHC" hanya -0.048313, dengan kolom "MCV" adalah -0.436041 dan keterkaitan hubungan data dengan kolom "AGE" juga hanya -0.412858. Ini berarti eritrosit yang rendah bukan menjadi sebab utama jika umur pasien terlalu tua/muda. Eritrosit yang rendah juga bukan menjadi penyebab tingginya/rendahnya kandungan leukosit dalam tubuh pasien, dll.
#
# Jadi intinya jika hubungan timbal-balik antar masing-masing kolom sangat tinggi seperti yang ditunjukkan oleh kolom "HAEMATOCRIT" dan "HAEMOGLOBINS" (0.973267) atau "MCH" dengan "MCV" (0.931804) mengindikasikan bahwa data tersebut sangat berkaitan/saling terkait antar satu dengan yang lain.

# %% [markdown]
# ### 1.1. Melakukan Proses Analisis Sederhana dengan Filter

# %%
"""
Menampilkan kolom data berdasarkan tipe data yaitu int dan object dari variabel "data_patient_treatment"
sedangkan tipe data float yang ada di dalam variabel "data_patient_treatment" tidak dimunculkan
"""
data_patient_treatment.select_dtypes(include=["int", "object"]).tail(8)
# Out:
#       THROMBOCYTE  AGE SEX SOURCE
# 4404          110   92   F     in
# 4405          100   92   F     in
# 4406          112   92   F     in
# 4407           72   92   F     in
# 4408           70   92   F     in
# 4409          235   93   F    out
# 4410          187   98   F     in
# 4411          275   99   F    out

# %%
"""
Menampilkan kolom data berdasarkan tipe data float dari "data_patient_treatment"
sedangkan kedua tipe data yang lain (int dan object) tidak dimunculkan
"""
data_patient_treatment.select_dtypes(exclude=["int", "object"]).tail(29)
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE   MCH  MCHC    MCV
# 4383         30.2           9.8         3.45        6.3  28.4  32.5   87.5
# 4384         29.8          10.1         3.44        7.8  29.4  33.9   86.6
# 4385         30.7          10.1         3.48        7.4  29.0  32.9   88.2
# 4386         28.9           9.6         3.24        8.6  29.6  33.2   89.2
# 4387         26.3           8.6         2.89        6.3  29.8  32.7   91.0
# 4388         27.1           8.9         3.01        7.6  29.6  32.8   90.0
# 4389         25.8           8.3         2.83        6.0  29.3  32.2   91.2
# 4390         24.7           8.2         2.72        6.9  30.1  33.2   90.8
# 4391         24.4           7.9         2.70        5.9  29.3  32.4   90.4
# 4392         26.6           8.7         2.94        5.9  29.6  32.7   90.5
# 4393         31.9          10.7         3.30        8.3  32.4  33.5   96.7
# ...

# %%
"""
Menampilkan 7 data teratas dari 11 kolom yang ada di dalam variabel
DataFrame "data_patient_treatment" tetapi dengan kondisi hanya data pasien rawat inap saja
"""
data_in = data_patient_treatment[data_patient_treatment["SOURCE"] == "in"]

data_in.head(7)
# Out:
#     HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 11         54.0          16.6         7.61       10.0           88  21.8
# 12         31.7          10.4         4.91        9.7          348  21.2
# 23         53.0          16.3         7.54        4.3          112  21.6
# 24         34.6          11.2         4.42        7.0          152  25.3
# 25         34.7          11.5         4.50        5.1          135  25.6
# 26         32.5          10.6         4.19        1.6          111  25.3
# 27         25.4           8.2         3.27        5.4           90  25.1
#
#     MCHC   MCV  AGE SEX SOURCE
# 11  30.7  71.0    1   F     in
# 12  32.8  64.6    1   M     in
# 23  30.8  70.3    1   F     in
# 24  32.4  78.3    1   F     in
# 25  33.1  77.1    1   F     in
# 26  32.6  77.6    1   F     in
# 27  32.3  77.7    1   F     in

# %% [markdown]
# Output diatas menunjukkan bahwa variabel "data_in" menyimpan hasil penyaringan (filter) dengan kondisi yaitu menampilkan data dari kolom "SOURCE" yang bernilai in atau pasien yang berstatus sebagai rawat inap. Dengan kata lain nilai out (pasien berstatus sebagai rawat jalan) yang dimiliki oleh kolom "SOURCE" tidak tersimpan dan tidak ada di dalam variabel "data_in" karena variabel tersebut hanya khusus berisikan nilai in dari kolom "SOURCE" saja.

# %% [markdown]
# #### 1.1.1. Mencari trombosit rendah untuk orang dewasa normal (baik Pria/Wanita)

# %%
"""
Menampilkan 34 data terbawah dari keseluruhan kolom yang ada di dalam variabel DataFrame
"data_patient_treatment" dengan 3 kondisi yaitu pasien yang memiliki trombosit rendah untuk orang dewasa normal.
Trombosit rendah untuk orang dewasa normal menurut riset adalah kurang dari 150 (< 150)
dan range umur dari orang dewasa normal berkisar 19 - 65 tahun (>= 19 dan <= 65)

Ref: https://www.nhlbi.nih.gov/health/thrombocytopenia#:~:text=Thrombocytopenia%20is%20a%20condition%20that,is%20called%20a%20blood%20clot.

"""
low_thrombocyte = data_patient_treatment.loc[(data_patient_treatment["THROMBOCYTE"] < 150) &
                                             (data_patient_treatment["AGE"] >= 19) &
                                             (data_patient_treatment["AGE"] <= 65)]
low_thrombocyte.tail(34)
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 2920         38.6          13.6         4.54        7.3           50  30.0
# 2950         29.3          10.2         3.63        5.0           94  28.1
# 2970         37.1          12.4         4.65        4.6          130  26.7
# 2979         25.3           8.7         2.87        4.8           85  30.3
# 2984         23.5           8.0         2.76        4.0           60  29.0
# 3005         31.4          10.4         3.96       17.9          148  26.3
# 3049         40.9          14.3         4.67        2.3          128  30.6
# 3060         37.7          13.2         4.30        2.0           77  30.7
# 3084         40.7          14.1         4.59        4.3           35  30.7
# 3085         40.6          14.0         4.56        3.8           17  30.7
# 3086         40.0          13.6         4.49        4.4           15  30.3
# ...

# %% [markdown]
# Hasil diatas menunjukkan bahwa proses penyaringan data menggunakan 3 kondisi sudah sangat tepat dan berhasil. Variabel "low_thrombocyte" hanya menyimpan data-data trombosit pasien dewasa yang rendah dan tentunya pasien dewasa yang memiliki trombosit rendah tersebut harus berada di rentang umur orang dewasa yaitu 19 - 65 tahun. Walaupun pasien tersebut berada di rentang umur orang dewasa normal (19 - 65 tahun) tetapi pasien tersebut memiliki trombosit yang tinggi atau lebih dari 150, maka pasien tersebut tidak memenuhi syarat untuk disimpan di dalam variabel "low_thrombocyte". Begitu juga saat pasien yang memiliki trombosit rendah (kurang dari 150) tetapi tidak berada di rentang umur 19 - 65 tahun, maka pasien tersebut tidak termasuk ke dalam variabel "low_thrombocyte".
#
# Selanjutnya saya akan menampilkan jumlah keseluruhan dari pasien dewasa yang memiliki trombosit yang rendah yaitu dibawah 150 dari variabel "low_thrombocyte" berdasarkan jenis kelamin pasien tersebut.

# %%
"""
Menampilkan jumlah frekuensi data dari kolom "SEX" untuk mengetahui
seberapa banyak Pria/Wanita dewasa yang memiliki trombosit rendah (< 150)
"""
low_thrombocyte["SEX"].value_counts().sort_values(ascending = True)
# Out:
# F    179
# M    206
# Name: SEX, dtype: int64

# %% [markdown]
# Dari output diatas menunjukkan bahwa Wanita dewasa yang memiliki trombosit rendah tidak sebanyak Pria dewasa normal karena jumlah wanita yang memiliki trombosit rendah hanya 179 orang sedangkan pasien dewasa berjenis kelamin Pria ternyata sangat banyak yang memiliki trombosit rendah yang kurang dari 150 dengan jumlah sebanyak 206 orang.
#
# Selain itu, berdasarkan output diatas juga kita dapat mengetahui bahwa pasien yang memiliki trombosit rendah (< 150) dengan rentang umur 19 - 65 tahun (range umur dari orang dewasa) ternyata tidak terlalu banyak karena hanya berjumlah 385 orang saja. Hal ini belum dapat dipastikan secara pasti faktor yang mempengaruhi trombosit rendah di pasien dewasa dan dibutuhkan analisis lebih lanjut.
#
# Selanjutnya saya akan mencari tau terkait umur dari Pria & Dewasa normal yang paling banyak/memiliki kadar trombosit rendah yaitu kurang dari 150.

# %%
"""
Menampilkan jumlah frekuensi data dari kolom "AGE" untuk mengetahui
seberapa banyak umur Pria & Wanita Dewasa yang memiliki trombosit rendah (< 150)
"""
low_thrombocyte["AGE"].value_counts().sort_values(ascending = False)
# Out:
# 45    37
# 25    26
# 22    16
# 26    15
# 37    13
# 29    13
# 47    12
# 34    12
# 30    12
# 65    12
# 46    11
# 36    11
# 44    11
# 32    10
# 38    10
# 23    10
# 48     9
# 53     9
# 24     9
# 35     8
# 55     8
# 61     8
# 58     7
# 59     7
# 57     7
# 39     6
# 51     6
# 56     5
# 49     5
# 64     5
# 21     5
# 41     5
# 40     5
# 33     5
# 54     5
# 50     4
# 43     4
# 19     4
# 52     4
# 20     3
# 60     3
# 31     3
# 63     2
# 42     1
# 62     1
# 27     1
# Name: AGE, dtype: int64

# %% [markdown]
# Berdasarkan hasil output diatas dapat diketahui jika pasien dewasa (baik pasien berjenis kelamin Pria/Wanita) yang berumur 45 tahun paling sering/paling banyak mengalami penurunan kadar trombosit di dalam sel darah mereka. Hal ini sangat berisiko sebab jika orang dewasa normal memiliki kadar trombosit yang rendah, baik Wanita/Pria, akan sangat rentan mengalami pendarahan yang tidak terkontrol dan alhasil tidak dapat sistem pembekuan darah tidak dapat bekerja dengan sangat baik dalam menyembuhkan luka/menghentikan pendarahan.
#
# Analisis selanjutnya yaitu saya ingin menampilkan informasi terkait ada berapa banyak pasien yang memiliki kadar eritrosit yang terendah ataupun tertinggi berdasarkan jenis kelamin pasien atau dengan kata lain saya ingin mengetahui berapa banyak pasien yang terindikasi memiliki kelebihan/kekurangan sel darah merah (eritrosit).

# %% [markdown]
# #### 1.1.2. Menampilkan jumlah kadar eritrosit terendah dan tertinggi berdasarkan jenis kelamin pasien

# %%
"""
Melakukan proses penyaringan berdasarkan kolom data (filter)
dengan hanya menampilkan data-data dari kolom "SEX" dan "ERYTHROCYTE"
"""
data_eritrosit = data_patient_treatment.filter(items=["SEX", "ERYTHROCYTE"])
data_eritrosit.tail(12)
# Out:
#      SEX  ERYTHROCYTE
# 4400   F         2.55
# 4401   F         3.44
# 4402   F         3.24
# 4403   F         3.08
# 4404   F         3.42
# 4405   F         3.03
# 4406   F         3.48
# 4407   F         3.49
# 4408   F         3.67
# 4409   F         3.47
# 4410   F         3.15
# 4411   F         3.44

# %%
""""
Melakukan penyaringan data kembali dari variabel "data_eritrosit" dengan kondisi kadar
eritrosit harus kurang dari 4.60 (< 4.60) untuk pasien berjenis kelamin Pria dan Wanita
"""
low_erythrocyte_male_female = data_eritrosit[data_eritrosit["ERYTHROCYTE"] < 4.60]

low_erythrocyte_male_female.head()
# Out:
#    SEX  ERYTHROCYTE
# 4    M         4.23
# 5    M         4.53
# 8    F         4.54
# 10   M         4.57
# 13   M         4.40

# %%
# Menampilkan jumlah pasien berdasarkan jenis kelamin yang memiliki kandungan sel darah merah (eritrosit) terendah
low_erythrocyte_male_female["SEX"].value_counts().sort_values(ascending = True)
# Out:
# M     878
# F    1391
# Name: SEX, dtype: int64

# %% [markdown]
# Berdasarkan hasil diatas diketahui bahwa pasien dengan jenis kelamin Perempuan (ditulis dengan nilai F yaitu Female) paling banyak mengalami kekurangan eritrosit atau sel darah merah dibandingkan Pasien berjenis kelamin Pria. Hal ini dibuktikan setelah variabel "low_erythrocyte_male_female" menyimpan hasil filtering data dari kolom "ERYTHROCYTE" yang dimiliki oleh variabel "data_eritrosit" dimana variabel tersebut (variabel "data_eritrosit") hanya memiliki 2 kolom saja yaitu "SEX" dan "ERYTHROCYTE".
#
# Jumlah pasien perempuan yang mengalami kondisi rendahnya kadar eritrosit kurang dari 4.60 ada sebanyak 1.391 pasien perempuan sedangkan pasien pria hanya terdapat 878 orang yang mengalami rendahnya kadar eritrosit. Selanjutnya saya akan mencari berapa banyak pasien yang mengalami tingginya kadar eritrosit atau dengan kata lain memiliki lebih banyak kandungan sel darah merah di dalam tubuhnya.

# %%
""""
Memfilter data dari variabel "data_eritrosit" dengan kondisi kadar
eritrosit lebih dari 5.70 (> 5.70) untuk pasien berjenis kelamin Pria dan Wanita
"""
high_erythrocyte_male_female = data_eritrosit[data_eritrosit["ERYTHROCYTE"] > 5.70]

high_erythrocyte_male_female.tail(9)
# Out:
#      SEX  ERYTHROCYTE
# 3643   M         7.30
# 3695   F         6.28
# 3696   F         6.64
# 3795   M         5.77
# 3803   F         6.09
# 3828   M         5.98
# 3950   M         6.11
# 4152   F         5.93
# 4267   M         6.00

# %%
# Menampilkan jumlah pasien berdasarkan jenis kelamin yang memiliki kandungan sel darah merah (eritrosit) tertinggi
high_erythrocyte_male_female["SEX"].value_counts().sort_values(ascending = False)
# Out:
# M    210
# F     36
# Name: SEX, dtype: int64

# %% [markdown]
# Hasil diatas menunjukkan bahwa sebanyak 210 pasien berjenis kelamin Pria/Laki-Laki memiliki kandungan sel darah merah diatas atau melebihi 5.70 juta/mikroliter darah sedangkan hanya 36 pasien Perempuan yang memiliki kandungan sel darah merah melebihi 5.70 juta/mikroliter. Harus diingat bahwa memiliki kandungan sel darah merah yang melebihi batas normal sangat berbahaya sebab menurut riset dapat mengindikasikan tubuh kita mengalami dehidrasi, kanker/tumor yang muncul pada bagian tubuh tertentu, adanya kelainan pada hemoglobin, efek samping dari konsumsi obat, gangguan tidur, dll.
#
# Analisis terakhir dengan menggunakan teknik filter adalah mencari tau jumlah leukosit/kandungan sel darah putih untuk orang dewasa yang berada di range usia 19 - 65 tahun berdasarkan status rawat pasien (apakah pasien tersebut dikategorikan sebagai pasien rawat inap/rawat jalan) dan juga berdasarkan jenis kelamin pasien.

# %% [markdown]
# #### 1.1.3. Menampilkan jumlah total & rata-rata kadar dari kandungan leukosit untuk setiap pasien dewasa

# %%
"""
Melakukan proses penyaringan berdasarkan kolom data (filter)
dengan hanya menampilkan data-data dari kolom "AGE" dan "LEUCOCYTE"
"""
data_leukosit = data_patient_treatment.filter(items=["AGE", "LEUCOCYTE"])

data_leukosit.head(2)
# Out:
#    AGE  LEUCOCYTE
# 0    1        6.3
# 1    1       12.7

# %% [markdown]
# Setelah menyaring (filtering) data terhadap kolom "AGE" dan "LEUCOCYTE" dari variabel DataFrame "data_patient_treatment" dan disimpan di dalam variabel baru yaitu "data_leukosit", tahap selanjutnya adalah menyaring data berdasarkan rentang umur pasien dewasa (19 - 65 tahun). Hal ini dilakukan agar analisis sederhana yang dilakukan yaitu untuk melihat jumlah total keseluruhan ataupun nilai rata-rata dari kandungan leukosit yang dimiliki oleh para pasien dewasa dapat terfokus dan pembahasan dari analisisnya tidak meluas ke lain topik.

# %%
"""
Memfilter data yang ada di dalam kolom "AGE" dengan memprioritaskan umur pasien dewasa normal (19 - 65 tahun)
untuk diketahui jumlah total dari kadar kandungan leokosit dan tampilkan 22 data teratas dari variabel baru
"""
filtering_age_for_adult_patient = data_leukosit.loc[((data_leukosit["AGE"] >= 19) & (data_leukosit["AGE"] <= 65))]

filtering_age_for_adult_patient.head(22)
# Out:
#      AGE  LEUCOCYTE
# 476   19        6.4
# 477   19        5.6
# 478   19        8.0
# 479   19        5.8
# 480   19        9.1
# 481   19        5.8
# 482   19        7.4
# 483   19        3.4
# 484   19        9.2
# 485   19        6.0
# 486   19        2.5
# 487   19        7.0
# 488   19        2.0
# 489   19        4.0
# 490   19        4.3
# 491   19        3.4
# 492   19        4.0
# 493   19        1.5
# 494   19        5.2
# 495   19        3.1
# 496   19        9.1
# 497   19        4.6

# %%
"""
Menampilkan jumlah total keseluruhan (menggunakan fungsi "sum()") dari kadar kandungan leukosit/sel darah putih
yang dimiliki oleh para pasien dewasa. Dengan kata lain, kita akan menampilkan jumlah total keseluruhan dari kadar
kandungan sel darah putih tertinggi hingga terendah yang dialami oleh para pasien dewasa rumah sakit
"""
data_sum_leucocyte = filtering_age_for_adult_patient.groupby("AGE")["LEUCOCYTE"].sum().sort_values(ascending = False)

print(data_sum_leucocyte)
# Out:
# AGE
# 59    924.9
# 62    883.9
# 65    747.7
# 55    720.6
# 53    719.6
# 60    699.1
# 63    686.6
# 56    668.4
# 64    613.8
# 26    613.5
# 30    599.6
# 45    595.6
# 46    592.3
# 58    589.8
# 57    589.4
# 25    570.1
# 61    567.9
# 24    564.7
# 29    564.1
# 32    563.3
# 54    562.2
# 49    555.6
# 51    543.9
# 33    517.3
# 47    512.0
# 36    506.2
# 35    501.7
# 52    487.3
# 27    484.9
# 43    484.0
# 37    482.1
# 41    471.1
# 44    467.3
# 38    447.2
# 28    446.0
# 50    444.6
# 40    435.2
# 31    416.7
# 34    415.7
# 22    384.7
# 42    370.4
# 21    367.5
# 48    356.5
# 23    328.9
# 39    311.6
# 20    181.5
# 19    154.9
# Name: LEUCOCYTE, dtype: float64

# %% [markdown]
# Hasil diatas menunjukkan bahwasanya pasien dewasa dengan umur 59 tahun, jika dihitung total secara keseluruhan berdasarkan hasil uji leukosi antar masing-masing pasien yang memiliki kisaran umur orang dewasa (19 - 65 tahun), maka pasien yang berumur 59 tahun memiliki jumlah total yang sangat tinggi dan terbanyak dalam hal memiliki sel darah putih (leukosit) yakni 924.9. Tetapi hal ini tidak berakibat buruk ke pasien karena pada dasarnya perhitungan diatas bukan untuk mengetahui SEBERAPA BANYAKNYA pasien berumur dewasa yang mengalami kadar leukosit terbanyak melainkan hanya untuk mengetahui JUMLAH TOTAL DARI KADAR KANDUNGAN LEUKOSIT per masing-masing rentang umur dewasa saja.
#
# Selain informasi mengenai pasien yang berumur 59 tahun memiliki jumlah total dari kadar leukosit tertinggi (924.4), pasien dengan umur 19 tahun memiliki jumlah total terhadap kadar leukosit yang paling rendah diantara rentang umur yang lainnya yakni hanya 154.9. Hanya memiliki selisih nilai 26.6 dengan pasien yang berumur 20 tahun karena pasien dewasa yang masih berumur 20 tahun memiliki jumlah total dari kadar leukosit yang hanya sebesar 181.5 (terendah kedua setelah pasien berumue 19 tahun).
#
# Tahap selanjutnya adalah melakukan proses mencari sekaligus menampilkan nilai rata-rata dari kolom "LEUCOCYTE" per masing-masing rentang umur pasien dewasa yang melakukan test pemeriksaan darah di dalam laboratorium.

# %%
"""
Menampilkan nilai rata-rata dari kadar kandungan leukosit/sel darah putih yang dimiliki oleh para pasien yang berada
di kisaran umur orang dewasa normal yaitu 19 - 65 tahun. Dengan kata lain, kita akan menampilkan rata-rata kadar
kandungan sel darah putih dari yang terendah yang dialami oleh para pasien dewasa rumah sakit
"""
mean_leucocyte = filtering_age_for_adult_patient.groupby("AGE")["LEUCOCYTE"].mean().sort_values(ascending = True)

print(mean_leucocyte)
# Out:
# AGE
# 19     5.341379
# 25     6.196739
# 39     6.629787
# 23     6.712245
# 48     6.726415
# 24     7.058750
# 45     7.090476
# 22     7.124074
# 33     7.184722
# 38     7.331148
# 29     7.422368
# 30     7.495000
# 34     7.558182
# 20     7.562500
# 47     7.641791
# 37     7.775806
# 44     7.788333
# 32     7.823611
# 46     7.897333
# 36     7.909375
# 26     7.967532
# 21     7.989130
# 31     8.170588
# 28     8.259259
# 52     8.259322
# 57     8.420000
# 61     8.604545
# 42     8.613953
# 40     8.704000
# 41     8.724074
# 43     8.962963
# 27     8.979630
# 58     9.215625
# 55     9.238462
# 35     9.290741
# 49     9.416949
# 50     9.459574
# 63     9.670423
# 56     9.686957
# 54     9.693103
# 51     9.712500
# 64     9.742857
# 60     9.987143
# 65    10.242466
# 62    10.398824
# 53    10.903030
# 59    11.707595
# Name: LEUCOCYTE, dtype: float64

# %% [markdown]
# Berdasarkan hasil output diatas mengenai nilai rata-rata dari kandungan sel darah putih yang dmiliki oleh berbagai macam range umur pasien dewasa dapat diketahui bahwasanya pasien berumur 19 tahun memiliki rata-rata dari jumlah kandungan leukosit hanya sebesar 5.341379. Nilai rata-rata tersebut menjadikan pasien berumur 19 tahun merupakan pasien dewasa yang memiliki rata-rata kadar dari jumlah leukosit yang sangat rendah dan tidak banyak. Tetapi hal tersebut tidak terlalu aneh mengingat saat kita menampilkan jumlah total dari keseluruhan kadar kandungan leukosit, pasien yang berumur 19 tahun memiliki nilai total kandungan leukosit yang jauh sangat rendah yaitu hanya 154.9.
#
# Disamping itu, pasien yang berumur 59 tahun memiliki rata-rata kandungan leukosit yang sangat tinggi karena pasien dengan umur 59 tahun menghasilkan rata-rata kadar kandungan leukosit dengan jumlah sebanyak 11.707595.

# %% [markdown]
# ## 2. Data Preprocessing (Data Transformation) and Export DataFrame to CSV File Format

# %% [markdown]
# Setelah melakukan proses Exploratory Data Analysis menggunakan beberapa fungsi di dalam library Pandas serta juga melakukan analisis data sederhana, pada tahapan kali ini akan dilakukan beberapa proses pembersihan data karena untuk saat ini susunan data yang ada di dalam variabel DataFrame "data_patient_treatment" masih bersifat data kotor (dirty data). Maka dari itu untuk mengatasi permasalahan yang terjadi dengan dirty data yang saat ini berada di dalam variabel DataFrame "data_patient_treatment", saya akan melakukan beberapa proses pembersihan data yaitu sebagai berikut:
#
# 1. Melakukan perubahan format dalam penamaan kolom data yang semula ditulis dengan huruf kapital akan ditransformasikan menjadi huruf berformat str.title yaitu setiap huruf pertama di awal kalimat adalah kapital (H) dan huruf selanjutnya diikuti dengan huruf kecil (e).
# 2. Membuat copy variabel DataFrame yang nantinya variabel DataFrame hasil copy tersebut digunakan untuk keperluan data visualisasi karena nantinya kolom "Sex" dan "Status" yang ada di dalam variabel DataFrame "data_patient_treatment" akan ditransformasikan menjadi data numerik integer.
# 3. Mengubah nilai sekaligus tipe data yang ada di dalam kolom "Sex" dan "Status" menjadi bilangan binary dengan fungsi LabelEncoder dari Sklern.preprocessing.
# 4. Mengecek kembali nilai data duplikat yang ada di dalam variabel DataFrame "data_patient_treatment". Jika terdapat data duplikat maka akan segera dihilangkan dari baris data.
# 5. Mengecek kembali missing value/nilai data yang hilang yang ada di dalam masing-masing kolom dari variabel DataFrame "data_patient_treatment". Jika terdapat missing value di dalam suatu kolom maka akan segera dihapus dari baris data di kolom tersebut supaya data menjadi lebih konsisten dan terhindar dari mis-interpretasi.
# 6. Preprocessing terakhir yang akan saya lakukan adalah meng-export data yang telah ditransformasikan menjadi file Comma Separated Value (.csv) untuk tahap modelling dengan Algoritma Machine Learning.

# %%
# Mengubah format penamaan kolom yang ada di dalam variabel DataFrame "data_patient_treatment"
data_patient_treatment = data_patient_treatment.rename(columns={"HAEMATOCRIT": "Hematocrit", "HAEMOGLOBINS": "Hemoglobin",
                                                                "ERYTHROCYTE": "Erythrocyte", "LEUCOCYTE": "Leucocyte",
                                                                "THROMBOCYTE": "Thrombocyte", "MCH": "Mch", "MCHC": "Mchc",
                                                                "MCV": "Mcv", "AGE": "Age", "SEX": "Sex", "SOURCE": "Status"})

data_patient_treatment.columns
# Out:
# Index(['Hematocrit', 'Hemoglobin', 'Erythrocyte', 'Leucocyte', 'Thrombocyte',
#        'Mch', 'Mchc', 'Mcv', 'Age', 'Sex', 'Status'],
#       dtype='object')

# %%
"""
Membuat salinan/copy terhadap variabel DataFrame "data_patient_treatment".
Nama salinan dari variabel DataFrame adalah "copy_df_patient_treatment"
"""
copy_df_patient_treatment = data_patient_treatment.copy()

# Menampilkan 5 data teratas dari salinan variabel DataFrame (copy_df_patient_treatment)
copy_df_patient_treatment.head()
# Out:
#    Hematocrit  Hemoglobin  Erythrocyte  Leucocyte  Thrombocyte   Mch  Mchc  \
# 0        35.1        11.8         4.65        6.3          310  25.4  33.6
# 1        43.5        14.8         5.39       12.7          334  27.5  34.0
# 2        33.5        11.3         4.74       13.2          305  23.8  33.7
# 3        39.1        13.7         4.98       10.5          366  27.5  35.0
# 4        30.9         9.9         4.23       22.1          333  23.4  32.0
#
#     Mcv  Age Sex Status
# 0  75.5    1   F    out
# 1  80.7    1   F    out
# 2  70.7    1   F    out
# 3  78.5    1   F    out
# 4  73.0    1   M    out

# %%
"""
Melakukan transformasi/perubahan nilai dan tipe data untuk kolom "Sex" dan "Status" dari yang semula
string kategorikal menjadi bilangan integer numerik serta menampilkan 38 data teratas
"""
label_encoding_for_changing_data = LabelEncoder()

data_patient_treatment["Sex"] = label_encoding_for_changing_data.fit_transform(data_patient_treatment["Sex"])
data_patient_treatment["Status"] = label_encoding_for_changing_data.fit_transform(data_patient_treatment["Status"])

data_patient_treatment.head(38)
# Out:
#     Hematocrit  Hemoglobin  Erythrocyte  Leucocyte  Thrombocyte   Mch  Mchc  \
# 0         35.1        11.8         4.65        6.3          310  25.4  33.6
# 1         43.5        14.8         5.39       12.7          334  27.5  34.0
# 2         33.5        11.3         4.74       13.2          305  23.8  33.7
# 3         39.1        13.7         4.98       10.5          366  27.5  35.0
# 4         30.9         9.9         4.23       22.1          333  23.4  32.0
# 5         34.3        11.6         4.53        6.6          185  25.6  33.8
# 6         31.1         8.7         5.06       11.1          416  17.2  28.0
# 7         40.3        13.3         4.73        8.1          257  28.1  33.0
# 8         33.6        11.5         4.54       11.4          262  25.3  34.2
# 9         35.4        11.4         4.80        2.6          183  23.8  32.2
# 10        33.7        11.5         4.57       13.2          322  25.2  34.1
# ...

# %%
# Menampilkan tipe data dari 11 kolom yang ada di dalam "data_patient_treatment" setelah dilakukan proses transformasi
data_patient_treatment.dtypes
# Out:
# Hematocrit     float64
# Hemoglobin     float64
# Erythrocyte    float64
# Leucocyte      float64
# Thrombocyte      int64
# Mch            float64
# Mchc           float64
# Mcv            float64
# Age              int64
# Sex              int64
# Status           int64
# dtype: object

# %% [markdown]
# Dengan menggunakan fungsi LabelEncoder dari library SKlearn.preprocessing, saya telah berhasil mentransformasikan nilai dan tipe data dari kolom "Sex" dan "Status" menjadi data binary numerik (0 dan 1) dengan tipe data integer (int). Karena sebelumnya kedua kolom tersebut menggunakan data string kategorik yang masing-masing kedua kolom tersebut memiliki 2 jenis nilai data yaitu "F" dan "M" (Female dan Male) dari kolom "Sex" serta "out" dan "in" (status out untuk pasien rawat jalan dan status in untuk pasien rawat inap) dari kolom "Status".
#
# Alasan saya melakukan proses perubahan nilai dan tipe data dari kolom "Sex" dan "Status" adalah karena pada saat melakukan proses klasifikasi dengan Algoritma Machine Learning atau melakukan proses standarisasi nilai data, di dalam variabel DataFrame tidak boleh memiliki data string atau kolom yang masih bertipe data object. Maka dari itu untuk mengatasi permasalahan dan menghindari error di langkah ke depannya, saya melakukan proses perubahan nilai data dari kategorikal menjadi bilangan numerikal, khususnya untuk data yang ada di dalam kolom "Sex" dan "Status".

# %%
# Mengecek kembali apakah di dalam variabel DataFrame "data_patient_treatment" terdapat data duplikat/tidak
data_patient_treatment.duplicated().sum()
# Out:
# 0

# %%
"""
Setelah mengecek kembali apakah di dalam "data_patient_treatment" terdapat data duplikat/tidak,
selanjutnya adalah melakukan proses pengecekan kembali apakah masing-masing
kolom yang ada di dalam "data_patient_treatment" terdapat missing value/tidak
"""

data_patient_treatment.isnull().sum()
# Out:
# Hematocrit     0
# Hemoglobin     0
# Erythrocyte    0
# Leucocyte      0
# Thrombocyte    0
# Mch            0
# Mchc           0
# Mcv            0
# Age            0
# Sex            0
# Status         0
# dtype: int64

# %%
"""
Menyimpan/meng-export data yang telah dilakukan proses preprocessing
data (perubahan nama kolom dan transformasi nilai/tipe data pada kolom string) ke dalam file .CSV (Comma Separated Value)
"""
#data_patient_treatment.to_csv("../Dataset/Patient Treatment Data after Preprocessed.csv", index = False)
# Out:
# '\nMenyimpan/meng-export data yang telah dilakukan proses preprocessing\ndata (perubahan nama kolom dan transformasi nilai/tipe data pada kolom string) ke dalam file .CSV (Comma Separated Value)\n'

# %% [markdown]
# File dataset dengan nama Patient Treatment Data after Preprocessed.csv bertujuan untuk digunakan di dalam file python yang berbeda dari saat ini yang dimana file tersebut nantinya khusus untuk tujuan tahap pemodelan dengan beberapa Algoritma Machine Learning. Selain itu tujuan dari melakukan proses export data setelah dilakukan tahap transformasi data dari preprocessing adalah untuk proses dokumentasi dan melihat perbedaan dari data sebelum/sesudah dilakukan proses preprocessing.
#
# Setelah melakukan tahap preprocessing data, tahap selanjutnya adalah saya akan melakukan proses analisis data dengan beberapa grafik visualisasi yang dibuat menggunakan 2 library khusus yaitu Seaborn dan Matplotlib. Tahap analisis data dengan grafik visualisasi bertujuan untuk memberikan variasi baru yang lebih berwarna dan variatif dalam mengambil insight dari suatu data. Dengan grafik kita akan jauh lebih cepat memahami apa yang ingin disampaikan dari data tersebut. Sebagai contoh analisis yang telah kita lakukan di tahap Exploratory Data Analysis using Pandas, saya hanya menggunakan fungsi "value_counts()", "sum()", "mean()", dll, yang dimana hal tersebut tidak cukup menarik karena tidak berwarna dan kurang variatif sehingga pembaca akan merasa membosankan.

# %% [markdown]
# ## 3. Data Visualization

# %%
"""
Menampilkan perbandingan data antar status final yang memutuskan apakah pasien harus dirawat inap/rawat jalan
berdasarkan jumlah kadar kandungan sel darah putih (leukosit)
"""
plt.figure(figsize=(15, 8))

sns.barplot(x="Status", y="Leucocyte", hue="Status", data=copy_df_patient_treatment)
plt.suptitle("Perbandingan Status Final Decision untuk Pasien", y=1, fontsize=15)
plt.title("Status Final Decision ini Bertujuan untuk Memutuskan Apakah Pasien \n"
          "Harus Tetap Dirawat Inap/Rawat Jalan berdasarkan Jumlah Leukosit", fontsize=13, pad=13, loc="center")
plt.xlabel("Final Decision", fontsize=12)
plt.ylabel("Jumlah Kadar Leukosit", fontsize=12)
#plt.savefig("../Data Visualization/Perbandingan Status Pasien Rawat Inap & Rawat Jalan berdasarkan Kadar Leukosit.png")
plt.show()

# %% [markdown]
# Grafik batang diatas menunjukkan bahwasanya status pasien rawat inap (yang ditunjukkan dengan nilai in) memiliki jumlah kadar kandungan Sel Darah Putih/Leukosit terbanyak sehingga disarankan untuk melakukan proses rawat inap di rumah sakit tertentu. Sedangkan data dengan status pasien rawat jalan (ditunjukkan dengan nilai out) dari kolom "Status" memiliki jumlah kadar kandungan Sel Darah Putih/Leukosit yang tidak sebanyak para pasien yang disarankan untuk melaksanakan rawat inap karena pasien-pasien yang dikategorikan menjalani perawatan bukan inap (rawat jalan) dirasa sudah cukup oleh para Dokter/Perawat untuk melakukan proses rawat jalan dalam mengontrol jumlah kandungan leukosit yang dimiliki oleh masing-masing pasien.

# %%
"""
Membandingkan data terkait keputusan akhir yang menentukan apakah pasien harus tetap dirawat inap/sudah diizinkan
untuk boleh pulang dengan satu syarat yaitu harus tetap melakukan proses rawat jalan yang dikategorikan
berdasarkan jenis kelamin antar pasien (pria/wanita) yang jumlah leukosit tertinggi hingga terendah
"""
plt.figure(figsize=(15, 8))

sns.barplot(x="Status", y="Leucocyte", hue="Sex", data=copy_df_patient_treatment, palette=["tab:cyan", "tab:orange"])
plt.suptitle("Jenis Kelamin Pasien dengan 2 Status Berbeda (Rawat Inap/Rawat Jalan)", y=1, fontsize=15)
plt.title("Membandingan Jumlah Kandungan Leukosit yang dimiliki oleh Pasien Pria/Wanita antara Rawat Inap/Rawat Jalan",
          fontsize=13, pad=13, loc="center")
plt.xlabel("Final Decision", fontsize=12)
plt.ylabel("Jumlah Kadar Leukosit", fontsize=12)
#plt.savefig("../Data Visualization/Perbandingan Status Pasien antar jenis kelamin berdasarkan jumlah leukosit.png")
plt.show()

# %% [markdown]
# Berbeda dari grafik batang pertama, pada grafik batang diatas lebih mengutamakan perbandingan data yang ada di kolom "Sex" atau jenis kelamin pasien daripada data dari kolom "Status" itu sendiri. Walaupun bukan mengutamakan perbandingan data dari kolom "Status" tetapi perbandingan data antar jenis kelamin pasien tetap dikelompokkan berdasarkan status akhir dari hasil uji laboratorium yang menyatakan apakah pasien tersebut harus melakukan proses rawat inap/rawat jalan.
#
# Hal tersebut dapat kita lihat bahwasanya pada status yang menyatakan bahwa pasien harus melakukan proses rawat inap (nilai in pada kolom "Status"), pasien berjenis kelamin Laki-Laki/Pria adalah yang paling banyak melakukan proses rawat inap di rumah sakit karena mereka memiliki jumlah kadar kandungan Leukosit/Sel Darah Putih yang sangat banyak daripada pasien Wanita/Perempuan. Walaupun pasien berjenis kelamin Wanita yang melakukan proses rawat inap cukup banyak karena mereka juga di diagnosa memiliki jumlah Leukosit yang cukup banyak tetapi jumlah kandungan tersebut tidak sebanyak jumlah Leukosit yang dimiliki oleh pasien Pria yang juga sama-sama melakukan proses perawatan inap di rumah sakit.
#
# Hal itu juga sama berlaku jika melihat perbandingan data yang di miliki oleh status pasien dengan sistem perawatan dengan rawat jalan (nilai out pada kolom "Status") yang ternyata pasien berjenis kelamin Laki-Laki/Pria merupakan pasien yang cukup banyak melakukan proses pengontrolan kadar kandungan Leukosit dengan metode rawat jalan yang dimana pasien-pasien Pria ini di diagnosa memiliki jumlah kandungan Leukosit yang cukup banyak. Sedangkan pasien yang memiliki jenis kelamin Wanita juga ternyata cukup banyak yang harus tetap melakukan proses perawatan dengan sistem rawat jalan karena mereka juga sama-sama di diagnosa memiliki jumlah Sel Darah Putih/Leukosit yang tidak kalah banyak bahkan cenderung sangat tipis dengan pasien rawat jalan lainnya yang tentu saja berjenis kelamin Pria.

# %%
"""
Membandingkan data terkait keputusan akhir yang menentukan apakah pasien harus tetap dirawat inap/sudah diizinkan
untuk rawat jalan dengan dikelompokkan jenis kelamin antar pasien (pria/wanita) berdasarkan jumlah Eritrosit
"""
plt.figure(figsize=(15, 8))

sns.barplot(x="Status", y="Erythrocyte", hue="Sex", data=copy_df_patient_treatment, palette=["tab:green", "tab:blue"])
plt.suptitle("Jumlah Eritrosit/Sel Darah Merah berdasarkan Jenis Kelamin Pasien", y=1, fontsize=15)
plt.title("Perbandingan Data antar Jenis Kelamin Pasien yang Memiliki Kandungan \n "
          "Eritrosit Tinggi/Rendah dengan 2 Status Berbeda (Rawat Inap/Rawat Jalan)", fontsize=13, pad=13, loc="center")
plt.xlabel("Final Decision", fontsize=12)
plt.ylabel("Jumlah Kadar Eritrosit", fontsize=12)
#plt.savefig("../Data Visualization/Perbandingan Status Pasien antar jenis kelamin berdasarkan jumlah eritrosit.png")
plt.show()

# %% [markdown]
# Berbeda dari grafik batang pertama, pada grafik batang diatas lebih mengutamakan perbandingan data yang ada di kolom "Sex" atau jenis kelamin pasien daripada data dari kolom "Status". Walaupun bukan mengutamakan perbandingan data dari kolom "Status" tetapi perbandingan data antar jenis kelamin pasien tetap dikelompokkan berdasarkan status akhir dari hasil uji laboratorium yang menyatakan apakah pasien tersebut harus melakukan proses rawat inap/rawat jalan.
#
# Hal tersebut dapat kita lihat bahwasanya pada status yang menyatakan bahwa pasien harus melakukan proses rawat inap (nilai in pada kolom "Status"), pasien berjenis kelamin Laki-Laki/Pria adalah yang paling banyak melakukan proses rawat inap di rumah sakit karena mereka memiliki jumlah kadar kandungan sel darah merah/Eritrosit yang sangat banyak daripada pasien Wanita/Perempuan. Walaupun pasien berjenis kelamin Wanita yang melakukan proses rawat inap cukup banyak karena mereka di diagnosa memiliki jumlah sel darah merah/Eritrosit yang banyak juga tetapi tidak sebanyak jumlah Eritrosit yang dimiliki oleh pasien Pria yang juga sama-sama melakukan proses perawatan inap di rumah sakit.
#
# Hal itu juga sama berlaku jika melihat perbandingan data yang di miliki oleh status pasien yang harus tetap melakukan proses perawatan walaupun dengan sistem rawat jalan (nilai out pada kolom "Status") yang ternyata pasien berjenis kelamin Laki-Laki/Pria merupakan pasien yang paling banyak melakukan proses pengontrolan/perawatan walaupun dengan metode rawat jalan sekalipun (bukan perawatan yang mengharuskan pasien berdiam diri di rumah sakit melainkan melalui sistem monitoring rutin) yang dimana pasien-pasien Pria ini di diagnosa memiliki jumlah kandungan Eritrosit/sel darah merah yang sangat banyak. Sedangkan pasien yang memiliki jenis kelamin Perempuan/Wanita juga ternyata cukup banyak yang harus tetap melakukan proses perawatan dengan sistem rawat jalan karena mereka juga sama-sama di diagnosa memiliki jumlah sel darah merah yang tidak kalah banyak dibandingkan dengan pasien berjenis kelamin Pria.

# %%
# Melihat nilai korelasi/keterkaitan antar masing-masing data dari variabel DataFrame "data_patient_treatment"
plt.figure(figsize=(15, 8))

sns.heatmap(data_patient_treatment.corr(), cmap="Spectral", annot=True)
plt.suptitle("Korelasi/Keterkaitan Data di Masing-Masing Kolom", fontsize=15)
plt.title("Hubungan Timbal-Balik antara Kolom Data dalam bentuk Nilai Korelasi", fontsize=13, pad=13, loc="center")
#plt.savefig("../Data Visualization/Grafik Korelasi untuk Melihat Hubungan Sebab-Akibat antar Kolom.png")
plt.show()

# %% [markdown]
# Sebenarnya grafik heatmap diatas (atau yang biasa dikenal sebagai grafik peta panas) tujuannya adalah sama dengan fungsi ".corr()" yang dimana bertujuan untuk menampilkan nilai korelasi atau nilai hubungan timbal-balik antar kolom data dimana data tersebut bernilai numerik. Dengan mengetahui nilai korelasi yang ditunjukkan oleh grafik heatmap, kita dapat mengetahui apakah suatu kolom dengan kolom yang lain memiliki hubungan timbal-balik/keterhubungan yang sangat kuat atau tidak.
#
# Lalu untuk mengetahui informasi yang terkandung di dalam grafik heatmap kita harus mengetahui cara membaca nilai-nilai yang ditampilkan agar mendapatkan informasi yang ada di dalamnya dan mengambil kesimpulan apakah nilai data yang ada di dalam kolom tersebut saling memiliki keterkaitan atau tidak. Cara membaca grafik ini yaitu membaca secara vertikal/horizontal dengan memperhatikan nilai yang ada di dalam kotak sebagai penanda nilai korelasi. Berikut adalah penjelasan terkait nilai korelasi antar kolom yang ada di dalam variabel DataFrame "data_patient_treatment" setelah dilakukan proses preprocessing:
#
# 1. Kolom "Status" memiliki hubungan timbal-balik yang cukup baik dengan kolom "Hematocrit" karena kedua kolom ini memiliki nilai korelasi sebesar 0.27. Walaupun keterkaitan data antara kedua kolom tersebut tidak sebaik jika dilihat keterkaitan/hubungan timbal-balik antara kolom "Hematocrit" dan "Hemoglobin" yang memiliki nilai korelasi sebesar 0.97, tetap saja saya pikir keterkaitan antara kolom "Status" dengan kolom "Hematocrit" sudah cukup baik dan data-data yang ada di kedua kolom tersebut cukup saling berkaitan dan mempengaruhi.
#
# 2. Kolom "Status" dengan kolom "Age" atau Umur ternyata tidak saling berkaitan antar satu dengan yang lain karena nilai korelasi yang dimiliki oleh kedua kolom ini adalah -0.11. Hal tersebut menunjukkan bahwa rentang umur pasien tidak berpengaruh terhadap keputusan akhir apakah pasien tersebut harus tetap di rawat di rumah sakit (rawat inap) atau sudah boleh pulang dengan catatan pasien tersebut harus tetap melakukan pengecekan rutin di rumah sakit (rawat jalan).
#
# 3. Kolom "Sex" atau Jenis Kelamin dengan kolom "Thrombocyte" juga ternyata tidak saling berkaitan atau dengan kata lain tidak memiliki hubungan timbal-balik karena nilai korelasi yang dihasilkan adalah -0.081. Ini berarti Jenis Kelamin pasien tidak menjadi faktor utama apakah setiap pasien Pria sudah pasti memiliki trombosit rendah sedangkan pasien Wanita memiliki trombosit normal/melebihi jumlah normal. Begitu juga sebaliknya karena kedua kolom tersebut tidak saling terkait sehingga tidak ada hubungan sebab-akibat. Sedangkan kolom "Status" dengan kolom "Thrombocyte" memiliki cukup kerkaitan karena memiliki nilai korelasi sebesar 0.24. Itu artinya setiap pasien, baik pria/wanita, yang memiliki jumlah trombosit yang normal, kurang atau bahkan lebih banyak dari jumlah trombosit normal akan mempengaruhi kesimpulan akhir apakah pasien harus tetap menjalankan pemeriksaan di rumah sakit (rawat inap) atau melakukan pemeriksaan dengan jadwal rutin yang telah disepakati (rawat jalan).

# %%
"""
Menampilkan jumlah total persentase data dengan pie chart berdasarkan jumlah protein yang terkandung
di dalam Eritrosit (sel darah merah) antar jenis kelamin pasien
"""
plt.figure(figsize=(15, 8))

percentage_label = copy_df_patient_treatment.groupby("Sex")["Hemoglobin"].sum().reset_index()
plt.pie(percentage_label["Hemoglobin"], labels = percentage_label["Sex"], colors=["cyan", "yellow"], autopct = "%1.1f%%")
plt.suptitle("Perbandingan Komposisi antar Jenis Kelamin Pasien", y=1, fontsize=15)
plt.title("Nilai Persentase dari Jumlah Total \n Hemoglobin per masing-masing Jenis Kelamin Pasien",
          fontsize=13, pad=13, loc="center")
plt.legend()
#plt.savefig("../Data Visualization/Persentase Pasien berdasarkan Jenis Kelamin dari Jumlah Total Hemoglobin.png")
plt.show()

# %% [markdown]
# Insight yang dapat kita ambil dari pie chart diatas adalah mengetahui komposisi/pembagian nilai data yang ada di dalam kolom "Sex" berdasarkan jumlah total hemoglobin yang dimiliki oleh masing-masing pasien yaitu Laki-Laki (M) dan Perempuan (F). Sebagai catatan bahwasanya jika kita menggunakan pie chart maka nilai persentasenya harus memenuhi 100%, tidak boleh kurang dari 100% atau melebihi 100% dan nilai 100% tersebut merupakan persentase dari total keseluruhan antar label data yang ada di dalam pie chart. Pada pie chart jika ditotalkan antara nilai 54.4 dengan 45.6 akan menghasilkan nilai yaitu 100. Selain itu, label yang dimiliki oleh setiap pie chart tidak boleh melebihi 6 karena jika suatu pie chart memiliki banyak sekali label akan menyulitkan membaca grafik tersebut apalagi mendapatkan insight yang ada di dalamnya. Maka dari itu pie chart diatas sudah memenuhi standar kriteria dalam membuat suatu grafik pie karena label yang dimiliki hanya 2 (nilai 0 untuk Jenis Kelamin Wanita dan nilai 1 untuk Jenis Kelamin Pria) sehingga kita akan mudah dalam mengambil wawasan yang ada di dalamnya serta total persentase keseluruhannya adalah 100%.
#
# Pie chart diatas menunjukkan bahwasanya komposisi pasien yang memiliki jenis kelamin Pria memiliki komposisi terbanyak daripada pasien yang berjenis kelamin Wanita dengan jumlah persentase yaitu 54.4% sedangkan komposisi dari pasien berjenis kelamin Wanita hanya memiliki jumlah persentase yakni 45.6% saja. Jumlah persentase tersebut dilihat berdasarkan dari jumlah total Hemoglobin (protein yang terkandung di dalam Sel Darah Merah/Eritrosit) antar masing-masing jenis kelamin pasien.

# %%
"""
Menampilkan pembagian komposisi persentase terhadap nilai data rata-rata dari kolom
"Hematocrit" yang terbagi ke dalam 2 status final decision dalam penanganan
para pasien selanjutnya (rawat inap/rawat jalan) melalui pie chart
"""
plt.figure(figsize=(15, 8))

percentage_label = copy_df_patient_treatment.groupby("Status")["Hematocrit"].mean().reset_index()
plt.pie(percentage_label["Hematocrit"], labels = percentage_label["Status"],
        colors=["tab:green", "tab:olive"], autopct = "%1.1f%%")
plt.suptitle("Komposisi Perbandingan Nilai Rata-Rata per Status Penanganan", y=1, fontsize=15)
plt.title("Rata-Rata Persentase terhadap Data Hematocrit per Status \n "
          "Penanganan Pasien (in: Pasien Rawat Inap & out: Pasien Rawat Jalan)",
          fontsize=13, pad=13, loc="center")
plt.legend()
#plt.savefig("../Data Visualization/Rata-Rata Persentase terhadap Ukuran Kandungan Sel Darah Merah per Status Penanganan.png")
plt.show()

# %% [markdown]
# Insight yang dapat kita ambil dari pie chart diatas adalah mengetahui komposisi persentase terhadap nilai rata-rata dari kolom "Hematocrit" berdasarkan status final decision (keputusan akhir) dalam memutuskan proses penanganan pasien selanjutnya apakah dirawat inap/rawat jalan. Maka dari itu informasi yang dapat kita ambil dari grafik diatas adalah bahwasanya rata-rata persentase terhadap status penanganan pasien jika dilihat berdasarkan ukuran kandungan Sel Darah Merah di dalam darah manusia (Hematocrit) mayoritas lebih ke arah pasien rawat jalan (out) dengan jumlah persentase sebesar 52.2% sedangkan status penanganan pasien rawat inap sebesar 47.8%. Hal ini juga dapat menyimpulkan bahwasanya karena Hematocrit juga biasa digunakan dalam mendeteksi apakah seseorang menderita anemia (kekurangan darah) atau tidak, maka berdasarkan nilai rata-ratanya, sebanyak 52.2% pasien yang memiliki status penanganan rawat jalan (out) bukan merupakan pasien yang terindikasi menderita anemia/kekurangan darah. Sebaliknya sebanyak 47.8% pasien terindikasi menderita penyakit anemia sehingga harus dirawat intensif di dalam rumah sakit dengan status penanganan yaitu rawat inap (in).
#
# Sama halnya dengan ketentuan pie chart sebelumnya, pie chart harus memiliki jumlah total persentase mencapai 100% dan jika kita melihat pie chart pada output diatas maka jika ditotalkan antara nilai 52.2 dengan 47.8 akan menghasilkan nilai yaitu 100. Selain itu, label yang dimiliki oleh setiap pie chart tidak boleh melebihi 6 karena jika suatu pie chart memiliki banyak sekali label (lebih dari 6 nilai data pada legend gambar) akan menyulitkan para pembaca termasuk pembuat grafik tersebut untuk mendapatkan insight serta informasi penting yang terkandung di dalam sebuah pie chart. Maka dari itu pie chart diatas sudah memenuhi standar kriteria dalam membuat grafik pie chart karena label yang dimiliki hanya 2 (nilai in untuk status penanganan pasien Rawat Inap dan nilai in untuk status penanganan Pasien Rawat Jalan) sehingga kita akan mudah dalam mengambil wawasan yang ada di dalamnya serta total persentase keseluruhannya sudah mencapai 100%.

# %%
"""
Menampilkan hubungan keterkaitan antar kolom yang memiliki nilai korelasi salah dua
tertinggi yaitu 0.93 dari variabel "copy_df_patient_treatment" yang dibedakan berdasarkan status final decision pasien
"""
plt.figure(figsize=(15, 8))
markers_point_data = {"out": "*", "in": ">"}

sns.scatterplot(x="Mch", y="Mcv", hue="Status", style="Status", data=copy_df_patient_treatment,
                s=180, markers=markers_point_data)
plt.suptitle("Pola Hubungan Korelasi Tertinggi (0.93)", y=1, fontsize=15)
plt.title("Hubungan Korelasi Linear Positif antara Kolom \n "
          "Mch dan Mcv berdasarkan Kategori Status Perawatan", fontsize=13, pad=13, loc="center")
plt.xlabel("Jumlah Rata-Rata Hemoglobin di Sel Darah Merah", fontsize=12)
plt.ylabel("Nilai Ukuran Rata-Rata Sel Darah Merah", fontsize=12)
#plt.savefig("../Data Visualization/Grafik Scatterplot dengan Hubungan Sebab-Akibat Tertinggi (Kolom Mch dan Mcv).png")
plt.show()

# %% [markdown]
# Grafik scatterplot (atau yang biasa dikenal sebagai grafik pencar) menampilkan hubungan keterkaitan yang sangat erat antara data-data yang ada di dalam kolom "Mch" dengan "Mcv". Dapat dikatakan bahwa kedua kolom ini memiliki hubungan linear yang positif dan data-data dari kedua kolom tersebut memiliki alasan yang saling mempengaruhi antar satu dengan yang lain walaupun pada kasus diatas grafik scatterplot terbagi menjadi 2 warna yang menunjukkan perbedaan status perawatan pasien (rawat inap dengan nilai in ataupun rawat jalan dengan nilai out).
#
# Hal ini dapat disimpulkan bahwasanya setiap jumlah rata-rata dari Hemoglobin yang terdapat di dalam Sel Darah Merah (Eritrosit) akan sangat mempengaruhi ukuran terhadap nilai rata-rata yang akan dimiliki oleh setiap keping dari Sel Darah Merah.

# %%
"""
Menampilkan hubungan keterkaitan antar kolom yang memiliki nilai korelasi paling rendah yaitu -0.44 yakni kolom "Erythrocyte"
dengan kolom "Mcv" dari variabel "copy_df_patient_treatment" yang dikategorikan berdasarkan status final decision pasien
"""
plt.figure(figsize=(15, 8))

sns.scatterplot(x="Mcv", y="Erythrocyte", hue="Status", style="Status",
                data=copy_df_patient_treatment, s=180, markers=True)
plt.suptitle("Pola Hubungan Korelasi Terendah (-0.44)", y=1, fontsize=15)
plt.title("Hubungan Korelasi yang Sangat Rendah antara Kolom Mcv dan Erythrocyte (Sel Darah Putih) \n "
          "berdasarkan Perbedaan Kategori Status Perawatan Pasien (Rawat Inap/Rawat Jalan)", fontsize=13, pad=13, loc="center")
plt.xlabel("Nilai Ukuran Rata-Rata Sel Darah Merah", fontsize=12)
plt.ylabel("Jumlah Sel Darah Putih", fontsize=12)
#plt.savefig("../Data Visualization/Grafik Scatterplot dengan Hubungan Sebab-Akibat Terendah (Kolom Mcv dan Erythrocyte).png")
plt.show()

# %% [markdown]
# Walaupun grafik pencar diatas saling berkumpul di suatu titik tertentu dan sangat terlihat memiliki hubungan sebab-akibat yang cukup bagus tapi pada kenyataannya hubungan data seperti ini tidaklah cukup bagus dan tidak memiliki keterkaitan antar data di masing-masing kedua kolom karena walaupun datanya berkumpul tetapi tidak membentuk suatu pola linear positif seperti pada grafik pencar sebelumnya. Hal ini disebabkan karena pada realitanya kolom "Mcv" dan kolom "Erythrocyte" memiliki nilai korelasi paling rendah diantara yang lain yaitu -0.44 yang menunjukkan bahwa kedua kolom ini tidak saling terkait dan juga tidak memiliki hubungan sebab dan akibat. Namun hal ini cukup mengherankan sebab seharusnya data yang ada di dalam kolom "Erythrocyte" dan "Mcv" saling memiliki keterkaitan karena Eritrosit merupakan sel darah merah dan Mcv (Mean Corpuscular Volume) yang merupakan ukuran dari Sel Darah Merah yang ada di dalam diri manusia. Eritrosit mengartikan jumlah banyak/sedikitnya Sel Darah Merah yang dimiliki sedangkan Mcv atau Mean Corpuscular Volume adalah bentuk ukuran dengan nilai rata-rata dari jumlah Sel Darah Merah.
